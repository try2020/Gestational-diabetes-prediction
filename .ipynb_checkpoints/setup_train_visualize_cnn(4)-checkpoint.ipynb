# %%
import pandas as pd
import numpy as np
from gensim.models.word2vec import Word2Vec

# %%
#import relevant data
with_time = True
if with_time:
    control_data = pd.read_csv("../cleaned_data/control_w_time.csv", index_col = 0)
    case_data = pd.read_csv("../cleaned_data/case_w_time.csv", index_col = 0)
    all_events = pd.read_csv("../cleaned_data/events_id_w_time.csv", index_col = 0)
    word2vec_model = Word2Vec.load("../word2vec_model/w2vmodel_wt")
    
    control_demo = pd.read_csv("../cleaned_data/control_demo_wt.csv", index_col = 0)
    case_demo = pd.read_csv("../cleaned_data/case_demo_wt.csv", index_col = 0)
else:
    control_data = pd.read_csv("../cleaned_data/control.csv", index_col = 0)
    case_data = pd.read_csv("../cleaned_data/case.csv", index_col = 0)
    all_events = pd.read_csv("../cleaned_data/events_id.csv", index_col = 0)
    word2vec_model = Word2Vec.load("../word2vec_model/w2vmodel")
    
    control_demo = pd.read_csv("../cleaned_data/control_demo.csv", index_col = 0)
    case_demo = pd.read_csv("../cleaned_data/case_demo.csv", index_col = 0)

# %%
control_demo.head()
# Out:
#       subject_id  gender  AGE  AMERICAN INDIAN/ALASKA NATIVE  ASIAN  \
# 328     10019992       0   44                              0      0
# 1435    10078892       0   37                              0      0
# 2448    10114736       0   49                              0      0
# 4073    10182430       0   39                              0      0
# 4074    10182430       0   39                              0      0
#
#       BLACK/AFRICAN AMERICAN  HISPANIC/LATINO  OTHER  UNABLE TO OBTAIN  \
# 328                        0                0      0                 0
# 1435                       0                0      0                 0
# 2448                       0                0      0                 0
# 4073                       1                0      0                 0
# 4074                       0                0      1                 0
#
#       UNKNOWN  WHITE
# 328         0      1
# 1435        0      1
# 2448        0      1
# 4073        0      0
# 4074        0      0

# %%
#construct an input list of arrays with event index (start from 1)
control_temp = control_data.groupby("subject_id").apply(lambda x: x.eve_index.values)
case_temp = case_data.groupby("subject_id").apply(lambda x: x.eve_index.values)

control_temp = control_temp.sort_index()
case_temp = case_temp.sort_index()

# %%
control_patients = control_temp.index.values
case_patients = case_temp.index.values
all_patients = np.concatenate([control_patients,case_patients])

# %%
#construct labels
Y_control = np.zeros(len(control_patients))
Y_case = np.ones(len(case_patients))
Y = np.concatenate([Y_control,Y_case])

# %%
#set up demographic input layer 
#group by operation automatic sorts the subject id so demographic data is in the same order as events data)
X_demo_control = control_demo.sort_values(by="subject_id")
X_demo_case = case_demo.sort_values(by="subject_id")
X_demo = np.concatenate([X_demo_control.iloc[:,1:3].values ,X_demo_case.iloc[:,1:3].values])

# %%
#find maximum number of events(used for set the parameters of embedding layer
#all sequences of events are padded to the max length)
c_max = control_data.groupby("subject_id")["eve_index"].count().max()
ca_max = case_data.groupby("subject_id")["eve_index"].count().max()
max_num_event_patient = np.max([c_max,ca_max])

# %%
#contruct training set of sequences with paddings, so all the sequence has the same length of max_length, 
#with 0s padded before in shorter sequences
np.random.seed(seed=6250)
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_control = [np.array(events).astype("int") for events in control_temp]
X_case = [np.array(events).astype("int") for events in case_temp]
X_all = np.concatenate([X_control,X_case])

X = pad_sequences(X_all, maxlen=None)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
X
# Out:
# array([[    0,     0,     0, ..., 35322, 30848, 31782],
#        [    0,     0,     0, ..., 29340,   114, 29340],
#        [    0,     0,     0, ..., 32824, 34157, 33014],
#        ...,
#        [    0,     0,     0, ..., 32170, 32170, 36806],
#        [    0,     0,     0, ..., 12585, 20475, 36807],
#        [    0,     0,     0, ..., 30594, 35881, 36807]], dtype=int32)

# %%
print(X[0].shape[0])
print (X.shape)
print (Y.shape)
# Out:
# 842
# (438, 842)
# (438,)

# %%
#shuffle
shuffled_index = np.random.permutation(len(all_patients))

#split train, dev, test set 7:1:2
train_index = shuffled_index[:int(len(all_patients)*0.7)]
dev_index =  shuffled_index[int(len(all_patients)*0.7):int(len(all_patients)*0.8)]
test_index =  shuffled_index[int(len(all_patients)*0.8):]

# %%
print (shuffled_index.shape)
print (train_index.shape, dev_index.shape, test_index.shape)
# Out:
# (438,)
# (306,) (44,) (88,)

# %%
all_patients_shuffle = all_patients[shuffled_index]

Y_train = Y[train_index]
Y_dev = Y[dev_index]
Y_test = Y[test_index]

X_train = X[train_index]
X_dev = X[dev_index]
X_test = X[test_index]

X_demo_train = X_demo[train_index]
X_demo_dev = X_demo[dev_index]
X_demo_test = X_demo[test_index]

# %%
#contruct embedding matrix dim of (number of different events, dim of embedding)
num_events = len(all_events)
print(num_events)
# Out:
# 36769

# %%
dim_embedding = len(word2vec_model.wv["1"])

# %%
print(dim_embedding)
# Out:
# 100

# %%
#contruct embedding matrix dim of (number of different events, dim of embedding)
num_events = len(all_events)
dim_embedding = len(word2vec_model.wv["1"])
#adding the dummy row for padding at index "0"
embedding_matrix = np.zeros((num_events+1, dim_embedding))
for i in range(1, num_events):
    embedding_matrix[i] = word2vec_model.wv[i]

# %%
embedding_matrix
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.65899014, -0.31489101, -0.03198135, ..., -0.31628633,
#          0.01713326,  0.02221249],
#        [-0.50833392, -0.14767984,  0.01217468, ...,  0.00226545,
#          0.09520426,  0.18843877],
#        ...,
#        [-0.20115116,  0.04379302,  0.00378813, ..., -0.03426295,
#          0.24104443, -0.08053544],
#        [-0.28696933, -0.1629563 , -0.1262079 , ..., -0.01282212,
#          0.19591483, -0.04550172],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
#set up the model
from keras.layers import Conv1D, Dense, Input,GlobalMaxPooling1D, MaxPooling1D, concatenate, Embedding,BatchNormalization, Dropout
from keras.optimizers import SGD, Adam, RMSprop,Nadam
from keras.models import Model
from keras.models import load_model
from keras.initializers import glorot_normal

input_events = Input(shape=(max_num_event_patient,))
init = glorot_normal(seed = 6250)

#embedding layer
embedding_raw = Embedding(40000, dim_embedding,embeddings_initializer = init, input_length=max_num_event_patient)(input_events)
embedding = BatchNormalization()(embedding_raw)
#1D conv
x_2 = Conv1D(filters = 4, kernel_size = 2,padding = "valid", activation='relu')(embedding)
x_3 = Conv1D(filters = 4, kernel_size = 3,padding = "valid", activation='relu')(embedding)
x_4 = Conv1D(filters = 4, kernel_size = 4,padding = "valid", activation='relu')(embedding)
x_5 = Conv1D(filters = 4, kernel_size = 5,padding = "valid", activation='relu')(embedding)

pool_2 = GlobalMaxPooling1D()(x_2)
pool_3 = GlobalMaxPooling1D()(x_3)
pool_4 = GlobalMaxPooling1D()(x_4)
pool_5 = GlobalMaxPooling1D()(x_5)

#need to adjust the shape for demographics if demo feature changes
#now its age, sex (tried ethnicity(one hot dim = 5) but not working well)

input_demo = Input(shape=(2,))

#concatenate max_pooling results
patient_embed = concatenate([input_demo,pool_2, pool_3,pool_4,pool_5])

#fully connected part
dense1 = Dense(6, activation = "relu")(patient_embed)
dense1 = Dropout(0.2)(dense1)
output = Dense(1, activation = "sigmoid" )(dense1)

model = Model(inputs=[input_events, input_demo], outputs=output)
model.compile(optimizer=Nadam(lr = 0.0005),loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/keras/optimizers/optimizer_v2/nadam.py:78: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Nadam, self).__init__(name, **kwargs)

# %%
model.fit([X_train, X_demo_train],Y_train, epochs=100,batch_size =64,shuffle=True,validation_data=([X_dev, X_demo_dev], Y_dev))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 4s 352ms/step - loss: 0.6614 - accuracy: 0.6438 - val_loss: 0.6482 - val_accuracy: 0.7045
# Epoch 2/100
# 5/5 [==============================] - 1s 291ms/step - loss: 0.5338 - accuracy: 0.6438 - val_loss: 0.6457 - val_accuracy: 0.7045
# Epoch 3/100
# 5/5 [==============================] - 2s 379ms/step - loss: 0.4951 - accuracy: 0.6438 - val_loss: 0.6428 - val_accuracy: 0.7045
# Epoch 4/100
# 5/5 [==============================] - 2s 350ms/step - loss: 0.4564 - accuracy: 0.6438 - val_loss: 0.6393 - val_accuracy: 0.7045
# Epoch 5/100
# 5/5 [==============================] - 2s 370ms/step - loss: 0.4229 - accuracy: 0.7320 - val_loss: 0.6386 - val_accuracy: 0.7045
# Epoch 6/100
# 5/5 [==============================] - 2s 316ms/step - loss: 0.3911 - accuracy: 0.7908 - val_loss: 0.6372 - val_accuracy: 0.7045
# Epoch 7/100
# 5/5 [==============================] - 2s 355ms/step - loss: 0.3807 - accuracy: 0.8137 - val_loss: 0.6351 - val_accuracy: 0.7045
# Epoch 8/100
# 5/5 [==============================] - 2s 382ms/step - loss: 0.3761 - accuracy: 0.8105 - val_loss: 0.6354 - val_accuracy: 0.7045
# Epoch 9/100
# 5/5 [==============================] - 2s 406ms/step - loss: 0.3696 - accuracy: 0.8399 - val_loss: 0.6310 - val_accuracy: 0.7045
# Epoch 10/100
# 5/5 [==============================] - 2s 308ms/step - loss: 0.3534 - accuracy: 0.8399 - val_loss: 0.6290 - val_accuracy: 0.7045
# Epoch 11/100
# 5/5 [==============================] - 2s 315ms/step - loss: 0.3586 - accuracy: 0.8366 - val_loss: 0.6283 - val_accuracy: 0.7045
# Epoch 12/100
# 5/5 [==============================] - 2s 334ms/step - loss: 0.3578 - accuracy: 0.8431 - val_loss: 0.6257 - val_accuracy: 0.7045
# Epoch 13/100
# 5/5 [==============================] - 2s 286ms/step - loss: 0.3406 - accuracy: 0.8693 - val_loss: 0.6242 - val_accuracy: 0.7045
# Epoch 14/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.3378 - accuracy: 0.8529 - val_loss: 0.6243 - val_accuracy: 0.7045
# Epoch 15/100
# 5/5 [==============================] - 2s 342ms/step - loss: 0.3246 - accuracy: 0.9085 - val_loss: 0.6207 - val_accuracy: 0.7045
# Epoch 16/100
# 5/5 [==============================] - 2s 371ms/step - loss: 0.3511 - accuracy: 0.8497 - val_loss: 0.6205 - val_accuracy: 0.7045
# Epoch 17/100
# 5/5 [==============================] - 3s 532ms/step - loss: 0.2983 - accuracy: 0.9216 - val_loss: 0.6200 - val_accuracy: 0.7045
# Epoch 18/100
# 5/5 [==============================] - 2s 292ms/step - loss: 0.3223 - accuracy: 0.8856 - val_loss: 0.6189 - val_accuracy: 0.7045
# Epoch 19/100
# 5/5 [==============================] - 1s 275ms/step - loss: 0.2988 - accuracy: 0.9216 - val_loss: 0.6199 - val_accuracy: 0.7045
# Epoch 20/100
# 5/5 [==============================] - 2s 340ms/step - loss: 0.3037 - accuracy: 0.9118 - val_loss: 0.6199 - val_accuracy: 0.7045
# Epoch 21/100
# 5/5 [==============================] - 1s 270ms/step - loss: 0.2977 - accuracy: 0.9281 - val_loss: 0.6181 - val_accuracy: 0.7045
# Epoch 22/100
# 5/5 [==============================] - 1s 293ms/step - loss: 0.2907 - accuracy: 0.9346 - val_loss: 0.6169 - val_accuracy: 0.7045
# Epoch 23/100
# 5/5 [==============================] - 1s 284ms/step - loss: 0.3028 - accuracy: 0.9183 - val_loss: 0.6162 - val_accuracy: 0.7045
# Epoch 24/100
# 5/5 [==============================] - 1s 279ms/step - loss: 0.2897 - accuracy: 0.9248 - val_loss: 0.6160 - val_accuracy: 0.7045
# Epoch 25/100
# 5/5 [==============================] - 1s 299ms/step - loss: 0.2761 - accuracy: 0.9412 - val_loss: 0.6157 - val_accuracy: 0.7045
# Epoch 26/100
# 5/5 [==============================] - 2s 306ms/step - loss: 0.2948 - accuracy: 0.9248 - val_loss: 0.6161 - val_accuracy: 0.7045
# Epoch 27/100
# 5/5 [==============================] - 2s 369ms/step - loss: 0.2674 - accuracy: 0.9575 - val_loss: 0.6144 - val_accuracy: 0.7045
# Epoch 28/100
# 5/5 [==============================] - 2s 378ms/step - loss: 0.2814 - accuracy: 0.9412 - val_loss: 0.6150 - val_accuracy: 0.7045
# Epoch 29/100
# 5/5 [==============================] - 2s 292ms/step - loss: 0.2785 - accuracy: 0.9477 - val_loss: 0.6134 - val_accuracy: 0.7045
# Epoch 30/100
# 5/5 [==============================] - 1s 281ms/step - loss: 0.2709 - accuracy: 0.9510 - val_loss: 0.6135 - val_accuracy: 0.7045
# Epoch 31/100
# 5/5 [==============================] - 1s 289ms/step - loss: 0.2682 - accuracy: 0.9510 - val_loss: 0.6123 - val_accuracy: 0.7045
# Epoch 32/100
# 5/5 [==============================] - 1s 265ms/step - loss: 0.2672 - accuracy: 0.9641 - val_loss: 0.6106 - val_accuracy: 0.7045
# Epoch 33/100
# 5/5 [==============================] - 2s 328ms/step - loss: 0.2618 - accuracy: 0.9673 - val_loss: 0.6102 - val_accuracy: 0.7045
# Epoch 34/100
# 5/5 [==============================] - 2s 314ms/step - loss: 0.2644 - accuracy: 0.9510 - val_loss: 0.6103 - val_accuracy: 0.7045
# Epoch 35/100
# 5/5 [==============================] - 2s 396ms/step - loss: 0.2694 - accuracy: 0.9510 - val_loss: 0.6095 - val_accuracy: 0.7045
# Epoch 36/100
# 5/5 [==============================] - 2s 338ms/step - loss: 0.2577 - accuracy: 0.9739 - val_loss: 0.6071 - val_accuracy: 0.7045
# Epoch 37/100
# 5/5 [==============================] - 2s 354ms/step - loss: 0.2495 - accuracy: 0.9706 - val_loss: 0.6065 - val_accuracy: 0.7045
# Epoch 38/100
# 5/5 [==============================] - 2s 327ms/step - loss: 0.2549 - accuracy: 0.9739 - val_loss: 0.6048 - val_accuracy: 0.7045
# Epoch 39/100
# 5/5 [==============================] - 2s 339ms/step - loss: 0.2492 - accuracy: 0.9739 - val_loss: 0.6056 - val_accuracy: 0.7045
# Epoch 40/100
# 5/5 [==============================] - 1s 284ms/step - loss: 0.2504 - accuracy: 0.9771 - val_loss: 0.6035 - val_accuracy: 0.7045
# Epoch 41/100
# 5/5 [==============================] - 1s 249ms/step - loss: 0.2589 - accuracy: 0.9673 - val_loss: 0.6034 - val_accuracy: 0.7045
# Epoch 42/100
# 5/5 [==============================] - 1s 265ms/step - loss: 0.2552 - accuracy: 0.9673 - val_loss: 0.6028 - val_accuracy: 0.7045
# Epoch 43/100
# 5/5 [==============================] - 1s 264ms/step - loss: 0.2489 - accuracy: 0.9739 - val_loss: 0.6021 - val_accuracy: 0.7045
# Epoch 44/100
# 5/5 [==============================] - 1s 256ms/step - loss: 0.2548 - accuracy: 0.9641 - val_loss: 0.6019 - val_accuracy: 0.7045
# Epoch 45/100
# 5/5 [==============================] - 1s 257ms/step - loss: 0.2674 - accuracy: 0.9510 - val_loss: 0.6000 - val_accuracy: 0.7045
# Epoch 46/100
# 5/5 [==============================] - 1s 251ms/step - loss: 0.2568 - accuracy: 0.9641 - val_loss: 0.5988 - val_accuracy: 0.7273
# Epoch 47/100
# 5/5 [==============================] - 1s 302ms/step - loss: 0.2581 - accuracy: 0.9542 - val_loss: 0.5969 - val_accuracy: 0.7045
# Epoch 48/100
# 5/5 [==============================] - 1s 258ms/step - loss: 0.2462 - accuracy: 0.9739 - val_loss: 0.5954 - val_accuracy: 0.7045
# Epoch 49/100
# 5/5 [==============================] - 1s 252ms/step - loss: 0.2461 - accuracy: 0.9739 - val_loss: 0.5940 - val_accuracy: 0.7273
# Epoch 50/100
# 5/5 [==============================] - 1s 267ms/step - loss: 0.2439 - accuracy: 0.9771 - val_loss: 0.5922 - val_accuracy: 0.7273
# Epoch 51/100
# 5/5 [==============================] - 1s 258ms/step - loss: 0.2531 - accuracy: 0.9673 - val_loss: 0.5905 - val_accuracy: 0.7273
# Epoch 52/100
# 5/5 [==============================] - 1s 247ms/step - loss: 0.2442 - accuracy: 0.9706 - val_loss: 0.5911 - val_accuracy: 0.7273
# Epoch 53/100
# 5/5 [==============================] - 1s 245ms/step - loss: 0.2458 - accuracy: 0.9739 - val_loss: 0.5891 - val_accuracy: 0.7273
# Epoch 54/100
# 5/5 [==============================] - 1s 260ms/step - loss: 0.2497 - accuracy: 0.9641 - val_loss: 0.5881 - val_accuracy: 0.7273
# Epoch 55/100
# 5/5 [==============================] - 1s 310ms/step - loss: 0.2527 - accuracy: 0.9608 - val_loss: 0.5881 - val_accuracy: 0.7273
# Epoch 56/100
# 5/5 [==============================] - 1s 256ms/step - loss: 0.2337 - accuracy: 0.9869 - val_loss: 0.5851 - val_accuracy: 0.7273
# Epoch 57/100
# 5/5 [==============================] - 1s 244ms/step - loss: 0.2410 - accuracy: 0.9739 - val_loss: 0.5862 - val_accuracy: 0.7273
# Epoch 58/100
# 5/5 [==============================] - 1s 241ms/step - loss: 0.2585 - accuracy: 0.9542 - val_loss: 0.5835 - val_accuracy: 0.7273
# Epoch 59/100
# 5/5 [==============================] - 1s 240ms/step - loss: 0.2527 - accuracy: 0.9608 - val_loss: 0.5805 - val_accuracy: 0.7273
# Epoch 60/100
# 5/5 [==============================] - 1s 240ms/step - loss: 0.2342 - accuracy: 0.9837 - val_loss: 0.5772 - val_accuracy: 0.7273
# Epoch 61/100
# 5/5 [==============================] - 1s 246ms/step - loss: 0.2495 - accuracy: 0.9673 - val_loss: 0.5744 - val_accuracy: 0.7273
# Epoch 62/100
# 5/5 [==============================] - 1s 238ms/step - loss: 0.2410 - accuracy: 0.9739 - val_loss: 0.5749 - val_accuracy: 0.7273
# Epoch 63/100
# 5/5 [==============================] - 2s 331ms/step - loss: 0.2366 - accuracy: 0.9804 - val_loss: 0.5738 - val_accuracy: 0.7273
# Epoch 64/100
# 5/5 [==============================] - 2s 362ms/step - loss: 0.2580 - accuracy: 0.9477 - val_loss: 0.5721 - val_accuracy: 0.7273
# Epoch 65/100
# 5/5 [==============================] - 1s 245ms/step - loss: 0.2398 - accuracy: 0.9739 - val_loss: 0.5694 - val_accuracy: 0.7273
# Epoch 66/100
# 5/5 [==============================] - 1s 250ms/step - loss: 0.2394 - accuracy: 0.9739 - val_loss: 0.5686 - val_accuracy: 0.7273
# Epoch 67/100
# 5/5 [==============================] - 1s 244ms/step - loss: 0.2471 - accuracy: 0.9641 - val_loss: 0.5658 - val_accuracy: 0.7273
# Epoch 68/100
# 5/5 [==============================] - 1s 253ms/step - loss: 0.2433 - accuracy: 0.9673 - val_loss: 0.5648 - val_accuracy: 0.7273
# Epoch 69/100
# 5/5 [==============================] - 1s 240ms/step - loss: 0.2305 - accuracy: 0.9837 - val_loss: 0.5638 - val_accuracy: 0.7273
# Epoch 70/100
# 5/5 [==============================] - 1s 249ms/step - loss: 0.2436 - accuracy: 0.9673 - val_loss: 0.5613 - val_accuracy: 0.7273
# Epoch 71/100
# 5/5 [==============================] - 1s 283ms/step - loss: 0.2351 - accuracy: 0.9771 - val_loss: 0.5584 - val_accuracy: 0.7273
# Epoch 72/100
# 5/5 [==============================] - 1s 253ms/step - loss: 0.2443 - accuracy: 0.9641 - val_loss: 0.5600 - val_accuracy: 0.7273
# Epoch 73/100
# 5/5 [==============================] - 1s 246ms/step - loss: 0.2301 - accuracy: 0.9837 - val_loss: 0.5627 - val_accuracy: 0.7500
# Epoch 74/100
# 5/5 [==============================] - 1s 246ms/step - loss: 0.2334 - accuracy: 0.9771 - val_loss: 0.5608 - val_accuracy: 0.7500
# Epoch 75/100
# 5/5 [==============================] - 1s 236ms/step - loss: 0.2304 - accuracy: 0.9804 - val_loss: 0.5584 - val_accuracy: 0.7273
# Epoch 76/100
# 5/5 [==============================] - 1s 269ms/step - loss: 0.2355 - accuracy: 0.9739 - val_loss: 0.5556 - val_accuracy: 0.7273
# Epoch 77/100
# 5/5 [==============================] - 1s 265ms/step - loss: 0.2189 - accuracy: 0.9935 - val_loss: 0.5526 - val_accuracy: 0.7273
# Epoch 78/100
# 5/5 [==============================] - 1s 273ms/step - loss: 0.2292 - accuracy: 0.9804 - val_loss: 0.5519 - val_accuracy: 0.7727
# Epoch 79/100
# 5/5 [==============================] - 1s 284ms/step - loss: 0.2265 - accuracy: 0.9837 - val_loss: 0.5480 - val_accuracy: 0.7500
# Epoch 80/100
# 5/5 [==============================] - 1s 245ms/step - loss: 0.2353 - accuracy: 0.9739 - val_loss: 0.5452 - val_accuracy: 0.7727
# Epoch 81/100
# 5/5 [==============================] - 1s 246ms/step - loss: 0.2347 - accuracy: 0.9739 - val_loss: 0.5438 - val_accuracy: 0.7500
# Epoch 82/100
# 5/5 [==============================] - 1s 244ms/step - loss: 0.2352 - accuracy: 0.9706 - val_loss: 0.5447 - val_accuracy: 0.7500
# Epoch 83/100
# 5/5 [==============================] - 1s 260ms/step - loss: 0.2272 - accuracy: 0.9771 - val_loss: 0.5431 - val_accuracy: 0.7500
# Epoch 84/100
# 5/5 [==============================] - 1s 237ms/step - loss: 0.2344 - accuracy: 0.9706 - val_loss: 0.5401 - val_accuracy: 0.7500
# Epoch 85/100
# 5/5 [==============================] - 1s 250ms/step - loss: 0.2319 - accuracy: 0.9739 - val_loss: 0.5365 - val_accuracy: 0.7500
# Epoch 86/100
# 5/5 [==============================] - 1s 255ms/step - loss: 0.2281 - accuracy: 0.9771 - val_loss: 0.5332 - val_accuracy: 0.7500
# Epoch 87/100
# 5/5 [==============================] - 1s 294ms/step - loss: 0.2254 - accuracy: 0.9804 - val_loss: 0.5318 - val_accuracy: 0.7727
# Epoch 88/100
# 5/5 [==============================] - 1s 263ms/step - loss: 0.2222 - accuracy: 0.9837 - val_loss: 0.5284 - val_accuracy: 0.7500
# Epoch 89/100
# 5/5 [==============================] - 1s 263ms/step - loss: 0.2273 - accuracy: 0.9771 - val_loss: 0.5268 - val_accuracy: 0.7727
# Epoch 90/100
# 5/5 [==============================] - 1s 283ms/step - loss: 0.2163 - accuracy: 0.9902 - val_loss: 0.5247 - val_accuracy: 0.7727
# Epoch 91/100
# 5/5 [==============================] - 1s 274ms/step - loss: 0.2268 - accuracy: 0.9771 - val_loss: 0.5210 - val_accuracy: 0.7727
# Epoch 92/100
# 5/5 [==============================] - 1s 266ms/step - loss: 0.2345 - accuracy: 0.9673 - val_loss: 0.5173 - val_accuracy: 0.7727
# Epoch 93/100
# 5/5 [==============================] - 1s 255ms/step - loss: 0.2417 - accuracy: 0.9575 - val_loss: 0.5138 - val_accuracy: 0.7955
# Epoch 94/100
# 5/5 [==============================] - 2s 357ms/step - loss: 0.2227 - accuracy: 0.9804 - val_loss: 0.5102 - val_accuracy: 0.7955
# Epoch 95/100
# 5/5 [==============================] - 3s 594ms/step - loss: 0.2275 - accuracy: 0.9739 - val_loss: 0.5060 - val_accuracy: 0.7955
# Epoch 96/100
# 5/5 [==============================] - 2s 330ms/step - loss: 0.2326 - accuracy: 0.9673 - val_loss: 0.5064 - val_accuracy: 0.7727
# Epoch 97/100
# 5/5 [==============================] - 2s 315ms/step - loss: 0.2377 - accuracy: 0.9608 - val_loss: 0.5028 - val_accuracy: 0.7727
# Epoch 98/100
# 5/5 [==============================] - 2s 265ms/step - loss: 0.2214 - accuracy: 0.9804 - val_loss: 0.5028 - val_accuracy: 0.7727
# Epoch 99/100
# 5/5 [==============================] - 2s 395ms/step - loss: 0.2317 - accuracy: 0.9673 - val_loss: 0.4995 - val_accuracy: 0.7727
# Epoch 100/100
# 5/5 [==============================] - 2s 416ms/step - loss: 0.2343 - accuracy: 0.9641 - val_loss: 0.4955 - val_accuracy: 0.7727

# %%
model.save('cnn-model.h5')

# %%
model.evaluate([X_test, X_demo_test], Y_test)
# Out:
# 3/3 [==============================] - 0s 30ms/step - loss: 0.5001 - accuracy: 0.7386
# [0.5000914931297302, 0.7386363744735718]

# %%
from sklearn import metrics
print(metrics.roc_auc_score(Y_test, model.predict([X_test, X_demo_test])))
# Out:
# 3/3 [==============================] - 0s 19ms/step
# 0.8118489583333334

# %%
#Visualize patient representation trained by CNN

# %%
#get embedding
patient_embedding=Model(inputs=[input_events, input_demo], outputs=patient_embed).predict([X, X_demo[0:438]])
# Out:
# 14/14 [==============================] - 0s 22ms/step

# %%
patient_embedding.shape
# Out:
# (438, 18)

# %%
from sklearn.manifold import TSNE
from time import time

# %%
#use t-sne to visualize patient representations in control group and case group
print("Computing t-SNE embedding")
tsne = TSNE(n_components=2, perplexity =2,init='pca', random_state=0,method='exact')
t0 = time()
patient_tsne = tsne.fit_transform(patient_embedding)

t1 = time()
print("t-SNE: %.2g sec" % (t1 - t0))

import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from sklearn.utils import check_random_state

fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(1,1,1)
plt.scatter(patient_tsne[:,0], patient_tsne[:,1], c=Y,cmap=plt.cm.rainbow_r)
plt.title("t-SNE (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

plt.show()
# Out:
# Computing t-SNE embedding
# t-SNE: 5.5 sec

# %%
#Doing Kmeans upon learned feature embeddings

# %%
#get case embeddings
case_embedding = patient_embedding[Y==1]

# %%
case_embedding.shape
# Out:
# (146, 18)

# %%
from sklearn.cluster import KMeans
# %matplotlib inline

# %%
kmeans_wss=[]
kmeans_idx=[]
for i in range(2,20):

    kmeans_clustering = KMeans( n_clusters = i).fit(case_embedding)
    kmeans_idx.append(kmeans_clustering.labels_)
    kmeans_wss.append(kmeans_clustering.inertia_)

# %%
#find good # of clusters 
plt.plot(range(2,20), kmeans_wss)

# %%
#Visualize 3 clusters in case group using pateint representation

# %%
case_class = KMeans(n_clusters = 3).fit(case_embedding).labels_ +1

# %%
#visualize and tag tsne graph using kmeans result 
print("Computing t-SNE embedding")
tsne = TSNE(n_components=3, perplexity =13.7,init='pca', learning_rate=500,early_exaggeration=2.0,random_state=6250,method='exact')  
t0 = time()
case_tsne = tsne.fit_transform(case_embedding)
t1 = time()
print("t-SNE: %.2g sec" % (t1 - t0))
x_min, x_max = np.min(case_tsne, 0), np.max(case_tsne, 0)
case_tsne = (case_tsne - x_min) / (x_max - x_min)

plt.figure(figsize=(9,9))
ax = plt.subplot(111)
for i in range(case_tsne.shape[0]):
    plt.text(case_tsne[i, 0], case_tsne[i, 1], str(case_class[i]),
                color=plt.cm.Set1(case_class[i]/10.0),
                fontdict={'weight': 'bold', 'size': 9})

plt.xticks([]), plt.yticks([])
plt.title("t-SNE: %.2g sec" % (t1 - t0))
# Out:
# Computing t-SNE embedding
# t-SNE: 1.8 sec
# Text(0.5, 1.0, 't-SNE: 1.8 sec')

# %%
#TopK n-gram in Each Cluster

# %%
from nltk import ngrams
import operator

def topk(X_case, case_class, cluster,k,n):
    codes_class=[]
    d={}
    for i in np.where(case_class==cluster)[0]:
        codes_class += list(ngrams(X_case[i],n))
    for e in codes_class:
        d[e] = d.get(e,0)+1
    d2 = {k: v/float(sum(d.values())) for (k,v) in d.items()}

    sorted_code = sorted(d2.items(), key=operator.itemgetter(1),reverse=True)

    return [x[0] for x in sorted_code[:k]]

# %%
event_id_dict = dict(zip(all_events.eve_index,all_events.events))

# %%
def top_grams(event_pairs):
    return [tuple(event_id_dict[x] for x in tup) for (i,tup) in enumerate(event_pairs)]

# %%
import pprint
pp = pprint.PrettyPrinter()
for c in range(1,4):
    pp.pprint('cluster:' + str(c))
    onegram = topk(X_case,case_class,c,10,1)
    twogram = topk(X_case,case_class,c,10,2)
    threegram = topk(X_case,case_class,c,10,3)
    pp.pprint(top_grams(onegram))
    pp.pprint(top_grams(twogram))
    pp.pprint(top_grams(threegram))
    print("")
    print("")
# Out:
# 'cluster:1'
# [('acetaminophen',),
#  ('sodium chloride 0.9%  flush',),
#  ('docusate sodium',),
#  ('lactated ringers',),
#  ('ketorolac',),
#  ('timetoken366+day',),
#  ('milk of magnesia',),
#  ('ibuprofen',),
#  ('calcium carbonate',),
#  ('ondansetron',)]
# [('docusate sodium', 'calcium carbonate'),
#  ('calcium carbonate', 'milk of magnesia'),
#  ('milk of magnesia', 'bisacodyl'),
#  ('bisacodyl', 'ibuprofen'),
#  ('ketorolac', 'ketorolac'),
#  ('acetaminophen', 'docusate sodium'),
#  ('acetaminophen', 'ondansetron'),
#  ('ondansetron', 'docusate sodium'),
#  ('ibuprofen', 'ketorolac'),
#  ('lactated ringers', 'simethicone')]
# [('docusate sodium', 'calcium carbonate', 'milk of magnesia'),
#  ('calcium carbonate', 'milk of magnesia', 'bisacodyl'),
#  ('milk of magnesia', 'bisacodyl', 'ibuprofen'),
#  ('acetaminophen', 'ondansetron', 'docusate sodium'),
#  ('acetaminophen', 'docusate sodium', 'calcium carbonate'),
#  ('ondansetron', 'docusate sodium', 'calcium carbonate'),
#  ('metoclopramide', 'acetaminophen', 'ondansetron'),
#  ('bisacodyl', 'ibuprofen', 'ketorolac'),
#  ('ibuprofen', 'ketorolac', 'ketorolac'),
#  ('ketorolac', 'ketorolac', 'ketorolac')]
#
#
# 'cluster:2'
# [('acetaminophen',),
#  ('docusate sodium',),
#  ('sodium chloride 0.9%  flush',),
#  ('lactated ringers',),
#  ('timetoken366+day',),
#  ('ondansetron',),
#  ('bisacodyl',),
#  ('ibuprofen',),
#  ('calcium carbonate',),
#  ('milk of magnesia',)]
# [('docusate sodium', 'calcium carbonate'),
#  ('calcium carbonate', 'milk of magnesia'),
#  ('milk of magnesia', 'bisacodyl'),
#  ('acetaminophen', 'docusate sodium'),
#  ('lactated ringers', 'simethicone'),
#  ('bisacodyl', 'ibuprofen'),
#  ('ketorolac', 'ketorolac'),
#  ('acetaminophen', 'ondansetron'),
#  ('sodium chloride 0.9%  flush', 'acetaminophen'),
#  ('ondansetron', 'docusate sodium')]
# [('docusate sodium', 'calcium carbonate', 'milk of magnesia'),
#  ('calcium carbonate', 'milk of magnesia', 'bisacodyl'),
#  ('milk of magnesia', 'bisacodyl', 'ibuprofen'),
#  ('acetaminophen', 'docusate sodium', 'calcium carbonate'),
#  ('acetaminophen', 'ondansetron', 'docusate sodium'),
#  ('ondansetron', 'docusate sodium', 'calcium carbonate'),
#  ('bisacodyl', 'ibuprofen', 'ketorolac'),
#  ('ibuprofen', 'ketorolac', 'ketorolac'),
#  ('sodium chloride 0.9%  flush', 'acetaminophen', 'docusate sodium'),
#  ('ibuprofen', 'lactated ringers', 'simethicone')]
#
#
# 'cluster:3'
# [('acetaminophen',),
#  ('sodium chloride 0.9%  flush',),
#  ('docusate sodium',),
#  ('timetoken366+day',),
#  ('lactated ringers',),
#  ('ibuprofen',),
#  ('bisacodyl',),
#  ('ketorolac',),
#  ('calcium carbonate',),
#  ('milk of magnesia',)]
# [('docusate sodium', 'calcium carbonate'),
#  ('calcium carbonate', 'milk of magnesia'),
#  ('milk of magnesia', 'bisacodyl'),
#  ('acetaminophen', 'docusate sodium'),
#  ('ketorolac', 'ketorolac'),
#  ('insulin', 'insulin'),
#  ('bisacodyl', 'ibuprofen'),
#  ('acetaminophen', 'ondansetron'),
#  ('lactated ringers', 'simethicone'),
#  ('sodium chloride 0.9%  flush', 'acetaminophen')]
# [('calcium carbonate', 'milk of magnesia', 'bisacodyl'),
#  ('docusate sodium', 'calcium carbonate', 'milk of magnesia'),
#  ('acetaminophen', 'docusate sodium', 'calcium carbonate'),
#  ('insulin', 'insulin', 'insulin'),
#  ('milk of magnesia', 'bisacodyl', 'ibuprofen'),
#  ('ketorolac', 'ketorolac', 'ketorolac'),
#  ('ondansetron', 'docusate sodium', 'calcium carbonate'),
#  ('sodium chloride 0.9%  flush', 'acetaminophen', 'docusate sodium'),
#  ('acetaminophen', 'ondansetron', 'docusate sodium'),
#  ('ibuprofen', 'lactated ringers', 'simethicone')]

# %%
#model2 = Model(inputs = input_events_r,outputs = x_2_r)
model2 = Model(inputs = input_events,outputs = x_2)
model3 = Model(inputs = input_events,outputs = x_3)
model4 = Model(inputs = input_events,outputs = x_4)

# %%
model2.predict(X).shape
# Out:
# 14/14 [==============================] - 1s 22ms/step
# (438, 841, 4)

# %%
#the temperal dimention of output size is max_events - n 
patient_feature_weights2 = model2.predict(X).reshape(4, 438, 841)
patient_feature_weights3 = model3.predict(X).reshape(4, 438, 840)
patient_feature_weights4 = model4.predict(X).reshape(4, 438, 839)
# Out:
# 14/14 [==============================] - 0s 22ms/step
# 14/14 [==============================] - 1s 33ms/step
# 14/14 [==============================] - 1s 35ms/step

# %%
def get_top_events(filter_output, top_num = 500, filter_size = 2):
    top = filter_output.flatten().argsort()[-top_num:]
    
    top_feature_med = []
    top_feature_diag = []
    top_feature_proc = []
    
    event_width = filter_output.shape[1]
    for idx in top:
        patient_idx = int(np.floor(idx/event_width))
        event_idx =  idx%event_width
        real_patient_id = all_patients_shuffle[patient_idx]
        real_event_id = X[patient_idx,event_idx:event_idx+2]
        if np.sum(real_event_id) !=0:
            for eve in real_event_id:
                print(eve)
                if eve >= 16120:
                    top_feature_med.append(eve)
                elif eve < 16120 and eve >= 9440:
                    top_feature_proc.append(eve)
                elif eve < 9440 and eve > 0:
                    top_feature_diag.append(eve)
                
    top_counts_med = pd.Series(top_feature_med).value_counts()
    top_counts_diag = pd.Series(top_feature_diag).value_counts()
    top_counts_proc = pd.Series(top_feature_proc,dtype='float64').value_counts()
    
    top_counts_med = pd.DataFrame({"index": top_counts_med.index, "counts":top_counts_med})
    top_counts_diag = pd.DataFrame({"index": top_counts_diag.index, "counts":top_counts_diag})
    top_counts_proc = pd.DataFrame({"index": top_counts_proc.index, "counts":top_counts_proc})
    
    return top_counts_med, top_counts_diag, top_counts_proc

# %%
eve_list_med = []
eve_list_diag = []
eve_list_proc = []
for i in range(4):
    te2_med, te2_diag, te2_proc = get_top_events(patient_feature_weights2[i])
    te3_med, te3_diag, te3_proc = get_top_events(patient_feature_weights3[i])
    te4_med, te4_diag, te4_proc = get_top_events(patient_feature_weights4[i])
    
    eve_list_med.append(te2_med)
    eve_list_med.append(te3_med)
    eve_list_med.append(te4_med)
    
    eve_list_diag.append(te2_diag)
    eve_list_diag.append(te3_diag)
    eve_list_diag.append(te4_diag)
    
    eve_list_proc.append(te2_proc)
    eve_list_proc.append(te3_proc)
    eve_list_proc.append(te4_proc)
# Out:
# 30261
# 32075
# 33014
# 36080
# 32075
# 36806
# 32408
# 36330
# 0
# 26406
# 35645
# 35432
# 5517
# 35454
# 30213
# 33299
# 32157
# 32609
# 15079
# 969
# 30445
# 35322
# 10946
# 10946
# 31747
# 30692
# 5727
# 5632
# 32170
# 32170
# 28939
# 110
# 34253
# 33355
# 34157
# 34854
# 709
# 10875
# 35498
# 31551
# 15924
# 12485
# 33424
# 28892
# 34157
# 34157
# 33649
# 35881
# 2608
# 2608
# 370
# 5435
# 2884
# 7428
# 28476
# 20835
# 35454
# 34253
# 29367
# 29367
# 5260
# 36807
# 19394
# 27940
# 32554
# 32554
# 19584
# 14556
# 30206
# 32408
# 3624
# 331
# 112
# 34071
# 35452
# 35452
# 29794
# 33424
# 4333
# 35916
# 6633
# 6699
# 34157
# 34157
# 30692
# 32157
# 34854
# 35293
# 28638
# 30484
# 22984
# 23886
# 33014
# 34578
# 13874
# 12621
# 33515
# 32170
# 30848
# 29794
# 32006
# 28796
# 32554
# 34017
# 3863
# 3863
# 28623
# 28623
# 29953
# 32408
# 12622
# 20841
# 30848
# 32157
# 0
# 20495
# 35454
# 28623
# 10937
# 779
# 30848
# 29794
# 6634
# 6535
# 4848
# 4341
# 2336
# 6675
# 0
# 5465
# 36802
# 31982
# 28873
# 32381
# 5509
# 4116
# 26024
# 6541
# 33014
# 33355
# 19255
# 15805
# 18752
# 36807
# 34260
# 31809
# 28801
# 34900
# 36802
# 36358
# 12602
# 12638
# 36802
# 34716
# 33515
# 31853
# 35454
# 31853
# 34716
# 35322
# 35454
# 28623
# 36752
# 36080
# 5509
# 2292
# 29794
# 33424
# 34261
# 35881
# 34261
# 35881
# 28801
# 33014
# 5652
# 1767
# 6633
# 6699
# 32408
# 36330
# 22675
# 701
# 26050
# 27628
# 34157
# 35454
# 33820
# 32006
# 32006
# 31853
# 29821
# 30015
# 26406
# 2520
# 4333
# 28652
# 19264
# 28470
# 32075
# 36802
# 29535
# 32075
# 5727
# 5599
# 31425
# 30053
# 35394
# 2106
# 30800
# 31423
# 36752
# 32892
# 32554
# 36804
# 12591
# 28123
# 8593
# 8503
# 5415
# 6541
# 35388
# 30594
# 5415
# 26024
# 4829
# 29953
# 20985
# 20988
# 29535
# 30261
# 28055
# 28476
# 35454
# 31853
# 15875
# 16095
# 3030
# 1625
# 26061
# 5620
# 32006
# 32075
# 30722
# 32554
# 28623
# 28623
# 34637
# 29535
# 12749
# 15309
# 28378
# 12920
# 35454
# 35454
# 2187
# 4829
# 5676
# 36802
# 0
# 2466
# 5878
# 4019
# 26406
# 5492
# 34253
# 33355
# 32963
# 29171
# 34887
# 36752
# 34634
# 32006
# 34157
# 34017
# 15882
# 28476
# 33371
# 114
# 30710
# 112
# 26050
# 27628
# 34253
# 34253
# 33424
# 29535
# 33233
# 32006
# 26406
# 6973
# 31853
# 35322
# 30445
# 30635
# 36802
# 33295
# 12749
# 25008
# 5692
# 26024
# 28623
# 30848
# 29794
# 33424
# 33424
# 32006
# 3681
# 27939
# 33931
# 33014
# 30722
# 35881
# 16057
# 720
# 35454
# 31853
# 31289
# 32409
# 35388
# 34261
# 876
# 876
# 30053
# 36805
# 6643
# 35454
# 31853
# 31883
# 32892
# 28649
# 5496
# 26182
# 29953
# 35454
# 33424
# 29535
# 36330
# 28638
# 33424
# 29535
# 679
# 11781
# 34591
# 34253
# 1010
# 19393
# 28623
# 30848
# 28623
# 30848
# 7538
# 6194
# 19415
# 19472
# 36422
# 112
# 7488
# 7447
# 30060
# 35322
# 3009
# 26801
# 19603
# 19315
# 35388
# 34261
# 28623
# 34157
# 33949
# 30489
# 28623
# 34983
# 112
# 28623
# 29953
# 35454
# 5683
# 5695
# 32006
# 29535
# 33424
# 29535
# 8316
# 2279
# 28623
# 30848
# 28106
# 9817
# 35454
# 32408
# 33424
# 29535
# 0
# 26406
# 30594
# 34261
# 112
# 28623
# 32939
# 33102
# 35278
# 31853
# 35452
# 35047
# 33014
# 112
# 35452
# 33014
# 33404
# 29367
# 36752
# 36080
# 5376
# 6633
# 31747
# 30692
# 6973
# 26024
# 34642
# 112
# 26024
# 35454
# 28623
# 34157
# 29821
# 29821
# 29535
# 32554
# 36330
# 4333
# 33580
# 32006
# 5657
# 35454
# 35293
# 35772
# 34157
# 36806
# 34261
# 30848
# 1012
# 27888
# 28623
# 30848
# 34261
# 36802
# 36802
# 32554
# 693
# 15268
# 36330
# 32006
# 29535
# 29953
# 35454
# 34253
# 33580
# 32554
# 36730
# 32554
# 36802
# 32075
# 31353
# 35454
# 20495
# 20511
# 34424
# 31853
# 36584
# 35454
# 35454
# 30710
# 30722
# 33007
# 15308
# 282
# 28623
# 31883
# 36199
# 33515
# 112
# 28623
# 33580
# 36807
# 33865
# 33865
# 0
# 31853
# 35454
# 32157
# 28623
# 30848
# 32075
# 34260
# 34140
# 35394
# 30222
# 29171
# 12836
# 28106
# 33001
# 33515
# 0
# 32963
# 32147
# 35454
# 4333
# 4333
# 35025
# 32408
# 4829
# 26950
# 32170
# 32170
# 29535
# 32075
# 112
# 35432
# 20170
# 35454
# 34774
# 29953
# 6973
# 5415
# 9072
# 5727
# 4970
# 7481
# 4333
# 31683
# 5606
# 34253
# 36047
# 36047
# 31613
# 28623
# 30635
# 32006
# 31801
# 33515
# 32609
# 35388
# 28623
# 32159
# 28623
# 30848
# 28623
# 34157
# 10965
# 12276
# 34253
# 32006
# 34591
# 32006
# 31747
# 30692
# 34642
# 34642
# 32554
# 36802
# 4887
# 5695
# 28623
# 34157
# 31738
# 31747
# 32824
# 36807
# 31853
# 28623
# 34253
# 34253
# 19186
# 35454
# 26031
# 35454
# 5496
# 6973
# 11853
# 7570
# 6633
# 5496
# 26947
# 4059
# 29794
# 33424
# 34324
# 34324
# 26406
# 26406
# 19192
# 19371
# 29794
# 33424
# 31853
# 28644
# 12331
# 17435
# 29445
# 28623
# 35322
# 31289
# 26276
# 2700
# 30655
# 30635
# 32408
# 28623
# 32408
# 32408
# 4636
# 4790
# 6633
# 5415
# 31613
# 33515
# 2416
# 2336
# 31594
# 32006
# 15074
# 20959
# 18694
# 19415
# 35322
# 35322
# 33865
# 33865
# 19543
# 27941
# 35454
# 34642
# 26094
# 2721
# 28623
# 30848
# 35881
# 36807
# 34253
# 33820
# 35322
# 28623
# 0
# 6399
# 4276
# 11728
# 32609
# 34854
# 0
# 5921
# 24116
# 900
# 31289
# 31289
# 5688
# 5645
# 5680
# 5700
# 33014
# 33014
# 2700
# 26801
# 33055
# 35388
# 5492
# 5376
# 28623
# 31674
# 28339
# 10946
# 32006
# 33014
# 30202
# 35635
# 32609
# 32609
# 112
# 34017
# 15308
# 15111
# 32003
# 34634
# 35645
# 35645
# 745
# 27925
# 7517
# 2218
# 32006
# 32006
# 28623
# 28623
# 33515
# 33515
# 26406
# 2186
# 112
# 34632
# 4333
# 28670
# 6379
# 6379
# 33133
# 29379
# 33014
# 32037
# 36291
# 28994
# 112
# 112
# 31613
# 31867
# 34157
# 30484
# 29794
# 32799
# 33268
# 112
# 34160
# 112
# 0
# 5465
# 27888
# 18989
# 7480
# 4559
# 32609
# 28623
# 34632
# 34632
# 6973
# 5415
# 34591
# 34591
# 36806
# 36806
# 11371
# 11371
# 34157
# 33014
# 34642
# 34642
# 35454
# 34253
# 32075
# 32554
# 4401
# 4401
# 29535
# 29535
# 7800
# 8022
# 26406
# 6633
# 31853
# 2187
# 28623
# 34157
# 33520
# 34160
# 36806
# 26406
# 32408
# 34157
# 28777
# 28777
# 20891
# 20481
# 35200
# 32609
# 32170
# 32170
# 34157
# 34157
# 33424
# 29535
# 36802
# 36802
# 35452
# 35452
# 30892
# 31551
# 36802
# 112
# 36803
# 35454
# 26554
# 2157
# 31359
# 31359
# 31334
# 2602
# 34724
# 32892
# 30261
# 32075
# 8197
# 6407
# 2914
# 2914
# 34642
# 33133
# 29953
# 34253
# 32609
# 32609
# 5662
# 5632
# 32170
# 32170
# 6699
# 6699
# 26406
# 26406
# 29535
# 32554
# 937
# 27939
# 35454
# 35454
# 34157
# 32006
# 2106
# 2186
# 112
# 36330
# 31834
# 31834
# 28623
# 33515
# 29535
# 29535
# 14272
# 17334
# 4333
# 33515
# 3701
# 2502
# 32609
# 34253
# 2078
# 2274
# 0
# 26554
# 33133
# 29379
# 30119
# 34157
# 31499
# 30074
# 5498
# 5402
# 31289
# 31947
# 377
# 3885
# 33649
# 33649
# 32408
# 34550
# 8316
# 4754
# 6541
# 5645
# 34324
# 35645
# 28623
# 35452
# 30261
# 32075
# 33014
# 36802
# 33055
# 35388
# 29535
# 32075
# 35454
# 28623
# 30635
# 35322
# 35454
# 31867
# 35322
# 34157
# 34260
# 32159
# 33515
# 33515
# 19549
# 15240
# 35881
# 31051
# 332
# 7786
# 33244
# 33244
# 2502
# 4754
# 29535
# 29535
# 35322
# 32408
# 9259
# 167
# 29535
# 30692
# 4315
# 5567
# 35047
# 34017
# 32003
# 33133
# 31738
# 30692
# 9557
# 32147
# 28198
# 10224
# 32408
# 36330
# 34157
# 34157
# 28777
# 32408
# 30848
# 34108
# 30551
# 33439
# 32159
# 32609
# 33295
# 33295
# 28106
# 9817
# 112
# 28623
# 32006
# 33014
# 29794
# 33424
# 34262
# 32078
# 32006
# 33014
# 4333
# 33515
# 19434
# 19098
# 114
# 32408
# 28623
# 32006
# 34108
# 2438
# 713
# 15308
# 28623
# 30848
# 3009
# 7428
# 3863
# 6699
# 7576
# 35454
# 32824
# 30594
# 36805
# 19113
# 1952
# 2110
# 32159
# 32609
# 35454
# 31853
# 2700
# 8197
# 112
# 32408
# 5504
# 5366
# 36802
# 31853
# 35454
# 34157
# 35394
# 28949
# 33515
# 34324
# 28623
# 34157
# 4333
# 34854
# 34140
# 35618
# 15308
# 3681
# 27666
# 12920
# 32159
# 28638
# 35881
# 35467
# 32006
# 32006
# 32006
# 32006
# 31674
# 34017
# 26760
# 365
# 32006
# 32006
# 28563
# 18163
# 32408
# 30800
# 0
# 4315
# 15864
# 9819
# 30202
# 36397
# 31867
# 35452
# 30848
# 33424
# 114
# 114
# 30743
# 30213
# 28623
# 33312
# 31867
# 32865
# 7382
# 6435
# 35454
# 30484
# 31853
# 28623
# 7519
# 5496
# 28717
# 112
# 31853
# 31289
# 1012
# 27888
# 28623
# 30484
# 4758
# 2466
# 5415
# 6891
# 4940
# 26728
# 30016
# 33597
# 18483
# 20888
# 30928
# 31359
# 29794
# 33424
# 30722
# 35881
# 0
# 26406
# 32591
# 33610
# 31853
# 114
# 19318
# 19528
# 18479
# 16058
# 28994
# 33515
# 32554
# 32554
# 35278
# 36664
# 2688
# 11726
# 36807
# 5465
# 36802
# 35916
# 32408
# 36330
# 33424
# 29535
# 34324
# 28626
# 32003
# 112
# 18991
# 36802
# 30848
# 32006
# 33014
# 31342
# 31834
# 2470
# 19334
# 27938
# 26554
# 4072
# 5899
# 5615
# 13192
# 20474
# 32799
# 36807
# 112
# 112
# 31296
# 34724
# 36807
# 28574
# 4333
# 28670
# 33133
# 29379
# 35589
# 35589
# 6541
# 6541
# 9335
# 9335
# 33355
# 34157
# 32006
# 33014
# 36807
# 36807
# 35454
# 112
# 114
# 30484
# 36026
# 36026
# 3688
# 3688
# 2790
# 2790
# 28623
# 28623
# 34260
# 32159
# 30800
# 36807
# 2186
# 4315
# 29535
# 29535
# 32554
# 34260
# 36330
# 112
# 34642
# 34507
# 28623
# 32159
# 30800
# 32006
# 34253
# 31738
# 33424
# 29535
# 30848
# 32591
# 0
# 2502
# 32006
# 31613
# 36330
# 36330
# 32408
# 30848
# 10940
# 16321
# 4848
# 4848
# 29821
# 29821
# 19433
# 1012
# 35200
# 32609
# 3688
# 7418
# 32609
# 32609
# 28623
# 34157
# 33580
# 34140
# 26406
# 5625
# 32170
# 32170
# 31613
# 31853
# 35454
# 34253
# 36664
# 33649
# 33128
# 33128
# 35881
# 35881
# 5692
# 26947
# 33295
# 34253
# 9817
# 9659
# 33244
# 33244
# 26728
# 26728
# 34157
# 34157
# 35454
# 34253
# 35589
# 34324
# 29535
# 32075
# 32075
# 32159
# 31051
# 32006
# 10848
# 20492
# 5567
# 5824
# 12625
# 15533
# 32006
# 30009
# 34253
# 32408
# 34260
# 32609
# 7299
# 7299
# 30800
# 33014
# 0
# 1952
# 29794
# 33424
# 36108
# 36108
# 4315
# 7796
# 28623
# 34157
# 7447
# 2688
# 33453
# 35916
# 31051
# 30800
# 26801
# 2434
# 30800
# 30009
# 26404
# 26404
# 20831
# 24935
# 0
# 26868
# 30118
# 36802
# 1012
# 15984
# 30484
# 30484
# 30848
# 34517
# 6973
# 5476
# 30176
# 30445
# 30928
# 31359
# 16095
# 17435
# 28994
# 34157
# 33014
# 33014
# 1010
# 19434
# 34157
# 34642
# 30261
# 32075
# 33295
# 35454
# 32006
# 32006
# 26304
# 7486
# 4333
# 35916
# 30849
# 34262
# 28801
# 33133
# 19586
# 18940
# 32408
# 34550
# 32554
# 32554
# 31334
# 32006
# 30848
# 30848
# 32609
# 32408
# 32075
# 35933
# 28801
# 32554
# 28638
# 36802
# 28994
# 32006
# 34253
# 28623
# 2700
# 5695
# 30202
# 31374
# 30800
# 32075
# 26406
# 2186
# 7483
# 29953
# 28638
# 32003
# 35278
# 31296
# 33128
# 33128
# 33371
# 32447
# 32006
# 32006
# 33492
# 36802
# 28623
# 29958
# 35452
# 35452
# 1012
# 27888
# 32006
# 33133
# 33596
# 30016
# 35388
# 35388
# 29791
# 28892
# 7250
# 6388
# 282
# 15111
# 33014
# 112
# 32075
# 32554
# 36802
# 28623
# 30126
# 30126
# 32609
# 30848
# 34253
# 28623
# 35322
# 30848
# 30800
# 30800
# 35454
# 36584
# 28623
# 28623
# 28623
# 34724
# 7786
# 4315
# 32408
# 30848
# 32609
# 32902
# 36802
# 34424
# 36802
# 35619
# 33294
# 32408
# 4315
# 7451
# 2688
# 2486
# 32408
# 29981
# 35322
# 35142
# 19394
# 19394
# 33133
# 33133
# 20679
# 12749
# 112
# 112
# 11501
# 28378
# 32609
# 33285
# 32075
# 30594
# 6634
# 6634
# 4333
# 29238
# 32006
# 32006
# 14232
# 12966
# 884
# 20559
# 5492
# 5625
# 36422
# 31807
# 709
# 10875
# 34632
# 33355
# 32157
# 33515
# 35454
# 35454
# 28114
# 20985
# 30635
# 32006
# 282
# 9817
# 32891
# 33014
# 15268
# 35454
# 7014
# 32159
# 32006
# 33014
# 34642
# 33133
# 6973
# 6634
# 10940
# 16321
# 28211
# 28211
# 33424
# 29535
# 26406
# 4315
# 20497
# 28476
# 26554
# 2110
# 28850
# 34140
# 28801
# 33014
# 34157
# 30848
# 32892
# 36330
# 31947
# 28623
# 34642
# 34642
# 30848
# 35452
# 29821
# 34652
# 29171
# 33865
# 35432
# 4333
# 31853
# 35454
# 29535
# 29535
# 34157
# 34324
# 35916
# 32159
# 32865
# 32408
# 33580
# 32554
# 19255
# 721
# 34253
# 34253
# 4136
# 4136
# 33133
# 29379
# 35388
# 30176
# 35452
# 29218
# 32157
# 32006
# 34157
# 32006
# 0
# 7969
# 35322
# 34591
# 33453
# 34157
# 31423
# 30800
# 28892
# 30712
# 0
# 7321
# 29379
# 29379
# 6534
# 35454
# 112
# 112
# 15924
# 28097
# 30015
# 34716
# 33014
# 34578
# 20914
# 19588
# 2365
# 26406
# 34157
# 31551
# 2885
# 35454
# 7864
# 2606
# 35454
# 31867
# 33515
# 33515
# 28623
# 28623
# 33014
# 32075
# 3681
# 3681
# 9561
# 9561
# 30222
# 35452
# 26406
# 6973
# 112
# 112
# 29379
# 35461
# 34160
# 34160
# 18987
# 36802
# 36330
# 33295
# 29379
# 34157
# 28378
# 12920
# 30848
# 34253
# 5676
# 36802
# 30848
# 29794
# 36802
# 34253
# 173
# 9830
# 35454
# 31853
# 35454
# 31853
# 34642
# 34642
# 516
# 5643
# 36802
# 30635
# 36806
# 28574
# 11728
# 26061
# 114
# 29379
# 33014
# 33014
# 0
# 26734
# 28623
# 30710
# 976
# 27941
# 35469
# 28623
# 11815
# 11846
# 36802
# 30635
# 32075
# 35388
# 33424
# 32006
# 28623
# 30848
# 12920
# 14268
# 35454
# 28623
# 34253
# 34724
# 35454
# 28623
# 35432
# 4333
# 34774
# 34223
# 16346
# 10489
# 32075
# 30445
# 8593
# 8503
# 29329
# 112
# 31289
# 28623
# 26024
# 6541
# 112
# 28623
# 5283
# 5170
# 32865
# 29379
# 35388
# 30594
# 35454
# 112
# 30710
# 34887
# 28623
# 29794
# 35454
# 28623
# 19530
# 19157
# 31867
# 31289
# 4883
# 2884
# 35322
# 28623
# 677
# 677
# 30848
# 28623
# 34347
# 29960
# 33424
# 29535
# 112
# 112
# 36330
# 33596
# 3681
# 3681
# 9561
# 9561
# 10998
# 11828
# 32157
# 32609
# 28623
# 34983
# 33292
# 33295
# 32075
# 32609
# 112
# 112
# 4367
# 4829
# 112
# 28623
# 32006
# 32006
# 30206
# 33292
# 32075
# 31613
# 31334
# 30060
# 5199
# 5260
# 26061
# 5620
# 5496
# 6973
# 28623
# 30848
# 4156
# 11853
# 6973
# 6541
# 33014
# 34967
# 35454
# 30016
# 28623
# 34157
# 2790
# 2700
# 31081
# 30722
# 2700
# 7345
# 29379
# 29379
# 34017
# 32609
# 5799
# 26346
# 35454
# 32170
# 36752
# 114
# 30060
# 35322
# 34642
# 112
# 3373
# 4944
# 15308
# 19584
# 29953
# 32408
# 31159
# 34286
# 5376
# 5496
# 34253
# 112
# 28623
# 30848
# 30594
# 36358
# 35394
# 2106
# 19264
# 28470
# 36330
# 4333
# 29535
# 35454
# 19586
# 19395
# 35454
# 31853
# 35916
# 33573
# 28638
# 34253
# 35454
# 31867
# 29953
# 32408
# 19156
# 35454
# 34157
# 34017
# 112
# 33133
# 27888
# 19394
# 26024
# 5449
# 4186
# 4653
# 31853
# 34157
# 35881
# 36807
# 29060
# 29060
# 35454
# 31853
# 36807
# 26406
# 28623
# 33312
# 33424
# 29535
# 33014
# 35322
# 5692
# 26024
# 31683
# 36804
# 32075
# 32609
# 34652
# 34652
# 28991
# 32609
# 32609
# 31853
# 29794
# 33424
# 33665
# 33665
# 29953
# 35454
# 34632
# 33355
# 30710
# 32075
# 26306
# 26313
# 29379
# 29379
# 35454
# 35454
# 35388
# 31081
# 26276
# 2700
# 30778
# 33931
# 29794
# 33424
# 29821
# 29821
# 33133
# 33133
# 19434
# 19264
# 30848
# 32157
# 30848
# 36802
# 28644
# 4333
# 34716
# 33355
# 6442
# 35454
# 29379
# 29379
# 34157
# 32006
# 31868
# 35454
# 35454
# 28623
# 32554
# 32554
# 32075
# 34260
# 26406
# 5683
# 31359
# 30800
# 0
# 2700
# 26557
# 8593
# 16080
# 35454
# 33133
# 33133
# 5700
# 5701
# 29821
# 29821
# 29379
# 30060
# 34275
# 35469
# 29535
# 32157
# 29535
# 29535
# 33515
# 34636
# 34258
# 35452
# 36807
# 2158
# 35461
# 35454
# 36330
# 36752
# 29794
# 33424
# 173
# 173
# 4333
# 31683
# 20841
# 19431
# 0
# 32963
# 36802
# 34262
# 29535
# 29953
# 29379
# 35461
# 33424
# 29535
# 35293
# 35772
# 33133
# 33133
# 112
# 112
# 14666
# 27840
# 13088
# 34253
# 20085
# 15282
# 843
# 15427
# 21076
# 28581
# 33649
# 35881
# 5695
# 5496
# 19431
# 27938
# 32006
# 29060
# 34275
# 30722
# 33865
# 33865
# 35645
# 35645
# 10945
# 19530
# 33424
# 29535
# 112
# 112
# 19157
# 19134
# 32591
# 32963
# 32159
# 35278
# 34253
# 33820
# 30635
# 32774
# 28623
# 30848
# 35454
# 35454
# 1004
# 35454
# 28623
# 30848
# 2700
# 6421
# 33515
# 34253
# 8567
# 5874
# 19115
# 27909
# 34275
# 34261
# 26919
# 34253
# 34900
# 31334
# 28623
# 32892
# 33649
# 33649
# 32075
# 34260
# 34261
# 30722
# 0
# 7321
# 2110
# 2041
# 1010
# 35454
# 26947
# 4059
# 2503
# 29953
# 7369
# 7369
# 5268
# 5268
# 32147
# 29953
# 5574
# 6699
# 33580
# 32824
# 2502
# 7786
# 35454
# 34157
# 4333
# 32609
# 32554
# 32157
# 35454
# 28623
# 2466
# 2466
# 7391
# 3009
# 29535
# 32075
# 35322
# 28623
# 36330
# 36422
# 36730
# 32554
# 34253
# 34253
# 30594
# 35881
# 30710
# 31613
# 6633
# 5496
# 31738
# 30692
# 28945
# 4333
# 32609
# 35388
# 0
# 4186
# 35454
# 31853
# 33424
# 29535
# 31613
# 33515
# 35388
# 30594
# 29821
# 31982
# 33133
# 29379
# 28991
# 30594
# 28623
# 32865
# 2437
# 28623
# 20521
# 10998
# 34275
# 34275
# 30594
# 30848
# 29535
# 32075
# 34652
# 34471
# 33424
# 29535
# 1767
# 5680
# 6634
# 26024
# 24847
# 20582
# 28623
# 30848
# 29171
# 30222
# 35322
# 35322
# 28623
# 36807
# 29535
# 29535
# 31738
# 31747
# 31738
# 31747
# 6892
# 35454
# 34774
# 29953
# 35454
# 34253
# 33424
# 29535
# 5509
# 2292
# 30848
# 31359
# 27025
# 6541
# 34157
# 36806
# 30848
# 29794
# 33424
# 29535
# 35645
# 35645
# 6438
# 4966
# 4142
# 34642
# 4754
# 528
# 28638
# 35498
# 33359
# 33359
# 32075
# 33515
# 31853
# 31853
# 27938
# 19549
# 2502
# 2606
# 1014
# 19571
# 36806
# 36806
# 7428
# 2721
# 32554
# 32554
# 32554
# 32554
# 29794
# 29535
# 30635
# 30635
# 32006
# 36584
# 1013
# 27939
# 8197
# 6407
# 32609
# 31853
# 19330
# 19571
# 6699
# 5645
# 18784
# 19180
# 5695
# 5695
# 35452
# 35452
# 34493
# 36108
# 28623
# 34157
# 29794
# 33424
# 32006
# 34160
# 15308
# 12633
# 33649
# 33649
# 29953
# 35454
# 114
# 32409
# 30800
# 36807
# 36806
# 36806
# 32774
# 32774
# 4754
# 2315
# 31853
# 35452
# 12280
# 36807
# 5563
# 3670
# 10964
# 11490
# 31334
# 2602
# 35322
# 32408
# 29379
# 29379
# 11856
# 26306
# 32044
# 32042
# 31853
# 33580
# 35452
# 28623
# 32006
# 32609
# 1711
# 35454
# 4315
# 26733
# 31853
# 35589
# 6699
# 5645
# 112
# 35322
# 34550
# 32609
# 28623
# 30015
# 32554
# 4333
# 28623
# 34157
# 19374
# 35454
# 6973
# 6973
# 32609
# 35388
# 32006
# 32006
# 36806
# 26862
# 29794
# 32075
# 32157
# 36080
# 28638
# 31853
# 2700
# 26304
# 112
# 28623
# 11181
# 20511
# 35454
# 32006
# 2218
# 2218
# 0
# 2502
# 35454
# 34253
# 28670
# 28670
# 34157
# 29972
# 15533
# 15589
# 2110
# 2110
# 35394
# 32157
# 0
# 9091
# 29473
# 29473
# 34253
# 33515
# 30015
# 33585
# 0
# 26406
# 35454
# 28623
# 36805
# 9823
# 34157
# 33014
# 33424
# 32075
# 34157
# 34157
# 30848
# 29794
# 36664
# 33649
# 33820
# 33585
# 30848
# 30848
# 33355
# 28623
# 30119
# 30119
# 36802
# 33014
# 26406
# 2186
# 33515
# 33515
# 35388
# 33649
# 30692
# 30692
# 4333
# 28670
# 4858
# 4401
# 33355
# 34157
# 9352
# 9352
# 7481
# 7481
# 34157
# 34157
# 32075
# 34260
# 3681
# 12591
# 31947
# 31947
# 33580
# 34140
# 112
# 30450
# 2158
# 4940
# 6541
# 5697
# 19181
# 712
# 7789
# 11639
# 35467
# 31959
# 32006
# 34591
# 35388
# 28991
# 1919
# 5695
# 28967
# 28967
# 34253
# 30445
# 35388
# 34275
# 7369
# 7486
# 32044
# 28892
# 32075
# 32159
# 7418
# 2700
# 28981
# 2110
# 33573
# 28920
# 31738
# 31738
# 32006
# 32006
# 5264
# 5264
# 35881
# 36804
# 33649
# 33649
# 11892
# 2259
# 35322
# 35322
# 35322
# 30848
# 26406
# 5695
# 0
# 26406
# 30848
# 32075
# 30692
# 30692
# 30800
# 33014
# 32408
# 32006
# 34636
# 34157
# 31289
# 32157
# 2187
# 2700
# 28623
# 30848
# 28623
# 28623
# 112
# 35322
# 2502
# 2606
# 34157
# 34157
# 28623
# 34157
# 34157
# 30848
# 112
# 34017
# 30261
# 32075
# 30848
# 31220
# 33014
# 29821
# 30848
# 34517
# 35454
# 28623
# 12920
# 15811
# 20891
# 20481
# 26302
# 26736
# 29535
# 30261
# 1010
# 19393
# 30261
# 32075
# 33133
# 33133
# 30800
# 34854
# 34258
# 32006
# 36802
# 28623
# 114
# 29379
# 32006
# 32006
# 35881
# 35881
# 36802
# 32006
# 5683
# 5683
# 33649
# 33649
# 33515
# 35454
# 7481
# 35454
# 34632
# 28623
# 12591
# 12625
# 112
# 33346
# 33014
# 33014
# 112
# 33346
# 32609
# 32609
# 30261
# 32075
# 4367
# 4850
# 32006
# 30800
# 32170
# 35394
# 4315
# 5567
# 35452
# 32963
# 30800
# 36080
# 2844
# 6366
# 112
# 31551
# 0
# 7427
# 5695
# 5376
# 35394
# 31359
# 32006
# 32159
# 36805
# 11857
# 0
# 26406
# 35469
# 32147
# 19330
# 19586
# 32554
# 30009
# 34275
# 30594
# 28623
# 35454
# 34642
# 112
# 10946
# 12591
# 4333
# 30176
# 6699
# 5563
# 4655
# 5724
# 5695
# 6973
# 31853
# 11867
# 33359
# 29535
# 34157
# 30848
# 33424
# 29535
# 30848
# 29794
# 35589
# 32006
# 33424
# 36802
# 26733
# 9260
# 35454
# 31853
# 26404
# 31853
# 29067
# 35454
# 30119
# 28623
# 33055
# 36291
# 0
# 2186
# 7486
# 2064
# 30848
# 32774
# 33355
# 36802
# 33649
# 33649
# 32609
# 32824
# 27888
# 27938
# 10727
# 1014
# 35388
# 36806
# 2336
# 5886
# 3009
# 7428
# 36324
# 33891
# 9557
# 32147
# 36026
# 31359
# 12360
# 35454
# 30635
# 36802
# 33424
# 32075
# 33014
# 36802
# 29535
# 32554
# 32408
# 29958
# 31499
# 36807
# 36806
# 31853
# 112
# 33268
# 32170
# 31738
# 28128
# 35293
# 5469
# 26024
# 33515
# 35454
# 34157
# 32006
# 36802
# 32006
# 3681
# 1012
# 4141
# 2157
# 4858
# 4401
# 30848
# 34140
# 34017
# 30129
# 26193
# 2466
# 5268
# 5197
# 31359
# 32006
# 112
# 33133
# 34157
# 30848
# 3688
# 4940
# 31613
# 30892
# 30722
# 35881
# 5496
# 9322
# 9362
# 8416
# 1952
# 3644
# 5620
# 6973
# 32006
# 32609
# 32609
# 35432
# 33563
# 30118
# 9291
# 4652
# 35454
# 34157
# 36021
# 30800
# 30129
# 36806
# 31867
# 35452
# 31853
# 30848
# 5645
# 5509
# 35322
# 32006
# 13192
# 20474
# 2606
# 2700
# 28623
# 30848
# 35454
# 28623
# 567
# 2606
# 28338
# 19117
# 18991
# 36802
# 30129
# 33649
# 33515
# 33515
# 35388
# 33649
# 0
# 31334
# 7026
# 5563
# 34157
# 30848
# 36802
# 30635
# 2186
# 2215
# 34157
# 32157
# 34157
# 34157
# 15879
# 10964
# 1004
# 35454
# 34157
# 30848
# 34642
# 112
# 35388
# 30722
# 33424
# 29535
# 32892
# 32824
# 27888
# 27940
# 28623
# 31947
# 32554
# 32157
# 34140
# 34716
# 32170
# 32170
# 34157
# 31334
# 34261
# 35881
# 34157
# 34157
# 33424
# 32006
# 32075
# 32075
# 5496
# 6973
# 33014
# 33014
# 2106
# 3688
# 30635
# 36802
# 6182
# 2884
# 35454
# 31853
# 36422
# 28638
# 34854
# 34854
# 35454
# 30484
# 29535
# 32006
# 28638
# 33515
# 29953
# 35454
# 5645
# 5414
# 2274
# 5496
# 36803
# 31359
# 35498
# 34017
# 35645
# 35645
# 33027
# 28623
# 29171
# 33027
# 27939
# 18943
# 30848
# 29794
# 32554
# 32609
# 32609
# 35388
# 26406
# 6699
# 32774
# 31947
# 33515
# 34324
# 33515
# 34632
# 32609
# 28638
# 36802
# 33491
# 9344
# 35454
# 33355
# 28623
# 30551
# 33439
# 31613
# 31613
# 34140
# 35618
# 19433
# 1013
# 31853
# 35025
# 12020
# 8600
# 26024
# 6541
# 32609
# 32006
# 29196
# 36049
# 2790
# 2606
# 4758
# 2434
# 32157
# 32609
# 32609
# 32609
# 33128
# 33128
# 32609
# 35388
# 32157
# 32609
# 31956
# 30800
# 28892
# 31594
# 5664
# 6633
# 28862
# 36021
# 32031
# 35360
# 32892
# 33424
# 33189
# 36803
# 0
# 2649
# 15308
# 14184
# 1768
# 5695
# 29794
# 30635
# 35645
# 35645
# 31289
# 35388
# 32006
# 36802
# 12625
# 10975
# 34261
# 30722
# 28623
# 32075
# 30848
# 30848
# 32554
# 32157
# 0
# 3624
# 34261
# 30722
# 4539
# 3624
# 35388
# 30722
# 34261
# 34261
# 32609
# 34275
# 34261
# 30722
# 30130
# 36803
# 2700
# 5695
# 29379
# 29379
# 28991
# 32447
# 2700
# 2083
# 1766
# 1766
# 32892
# 35339
# 32075
# 36802
# 30489
# 32170
# 34253
# 35986
# 3860
# 36806
# 33820
# 33133
# 33014
# 31867
# 36123
# 30800
# 34261
# 30722
# 29794
# 35388
# 36806
# 36806
# 32075
# 35388
# 36802
# 32075
# 30848
# 29794
# 30635
# 30635
# 33649
# 34261
# 32147
# 35454
# 36802
# 36802
# 6973
# 5476
# 31359
# 35322
# 112
# 35322
# 33355
# 28623
# 36505
# 36505
# 5496
# 3863
# 35322
# 32408
# 35388
# 34261
# 5197
# 5197
# 36026
# 36026
# 4333
# 32157
# 4754
# 7359
# 34157
# 31853
# 20832
# 20491
# 34253
# 114
# 7299
# 7299
# 20779
# 18739
# 34260
# 32159
# 33424
# 29535
# 32075
# 35933
# 36802
# 36802
# 33649
# 33649
# 34275
# 30594
# 32554
# 32554
# 32554
# 32554
# 32899
# 36802
# 31051
# 34051
# 35881
# 30885
# 11181
# 1012
# 33014
# 32609
# 34253
# 36807
# 35454
# 35454
# 35454
# 34253
# 31853
# 32157
# 35454
# 35454
# 31853
# 28623
# 32774
# 30530
# 36802
# 34157
# 32006
# 32554
# 34253
# 28623
# 112
# 112
# 30848
# 32075
# 33128
# 33128
# 32554
# 35388
# 34591
# 35452
# 31613
# 34160
# 34260
# 34260
# 33424
# 29535
# 33355
# 28623
# 29535
# 32075
# 30848
# 33424
# 34157
# 30848
# 30202
# 33424
# 28638
# 28638
# 32044
# 32042
# 2186
# 26949
# 33361
# 33361
# 30848
# 29794
# 32075
# 112
# 30848
# 29794
# 29535
# 29535
# 5877
# 26760
# 34258
# 29953
# 33355
# 28623
# 11371
# 11371
# 32159
# 32159
# 31289
# 32075
# 4315
# 7796
# 30206
# 30551
# 5470
# 5680
# 32006
# 28801
# 30484
# 36049
# 33359
# 33359
# 30848
# 30848
# 32609
# 35388
# 32006
# 32006
# 35454
# 35454
# 4333
# 4333
# 30635
# 30635
# 24889
# 12360
# 28994
# 33515
# 11856
# 26306
# 28623
# 28623
# 34652
# 35619
# 26406
# 5683
# 30848
# 30848
# 0
# 31853
# 31359
# 35619
# 36330
# 32006
# 34854
# 31594
# 32554
# 35388
# 5165
# 4655
# 33359
# 33359
# 35322
# 34591
# 35388
# 33649
# 35394
# 35394
# 3688
# 3688
# 12856
# 12856
# 5496
# 6634
# 32075
# 32075
# 31853
# 28191
# 36330
# 28717
# 36113
# 2606
# 29674
# 29953
# 32044
# 30202
# 32170
# 32170
# 33371
# 33371
# 32075
# 32554
# 34253
# 34253
# 28623
# 28623
# 36026
# 36026
# 0
# 34140
# 6065
# 4898
# 34253
# 29535
# 33027
# 33027
# 34253
# 32006
# 3094
# 2844
# 31853
# 31853
# 32006
# 32006
# 29473
# 35469
# 11186
# 19330
# 32170
# 32170
# 32170
# 32170
# 29455
# 33014
# 36802
# 36802
# 34253
# 32006
# 35454
# 34253
# 19333
# 19267
# 29535
# 32075
# 33133
# 29379
# 28638
# 30635
# 30635
# 30635
# 36802
# 33344
# 32075
# 36802
# 34253
# 34157
# 26406
# 2186
# 34223
# 31359
# 34275
# 28623
# 33133
# 33133
# 2315
# 7447
# 4313
# 5593
# 19343
# 33515
# 35454
# 112
# 32006
# 28623
# 15616
# 27501
# 32006
# 29535
# 30129
# 36802
# 29535
# 29535
# 4333
# 35916
# 4192
# 4192
# 34591
# 33492
# 31051
# 34652
# 7544
# 7511
# 29794
# 32892
# 2700
# 6438
# 35916
# 34517
# 6891
# 5899
# 33355
# 28623
# 28623
# 11561
# 4315
# 4315
# 26313
# 26313
# 32609
# 36807
# 31853
# 114
# 29794
# 33580
# 30848
# 30848
# 33133
# 35322
# 29791
# 35432

# %%
final_top_proc["events"].apply(lambda x: x[-3:]).values
# Out:
# array(['909', '909', '329', '649', '630', '119', '561', '909', '419',
#        'J36', '959', '918', '219', '039', '290', '766', '786', '783',
#        '497', 'G35', '004', '214', '828', '638', '500', '688', '510',
#        '965', '302', '713', '868', '393', '620', '671', '721', '699',
#        '110', 'I10', '398', '990', '592', '010', '509', '921', '920',
#        '831', '182', '030', '812', '809', '651', '909', '589', '580',
#        '970', '957', '532', '500', '580', '859', '639', '669', '785',
#        '199', '495', '696', '861', '871', '874', '770', '689', '788',
#        '798', '289', '252', '010', '129', '123', '489', '200', '341',
#        '410', '411', 'D62', '310', '322', '581', '473', '700'],
#       dtype=object)

# %%
eve_counts_d = pd.concat(eve_list_diag, axis = 0).groupby("index").sum().sort_values(by = "counts", ascending = False)[:]
final_top_diag = eve_counts_d.merge(all_events, how = "left", left_index = True, right_on = "eve_index")

eve_counts_p = pd.concat(eve_list_proc, axis = 0).groupby("index").sum().sort_values(by = "counts", ascending = False)[:]
final_top_proc = eve_counts_p.merge(all_events, how = "left", left_index = True, right_on = "eve_index")

eve_counts_m = pd.concat(eve_list_med, axis = 0).groupby("index").sum().sort_values(by = "counts", ascending = False)[:]
final_top_med = eve_counts_m.merge(all_events, how = "left", left_index = True, right_on = "eve_index")

# %%
final_top_diag
# Out:
#           counts  eve_index                events
# 21355898      64        112  0.9% sodium chloride
# 11108738      27       4333           5% dextrose
# 2013528       16       2700                   311
# 18729682      16       6973                   756
# 15580600      13       5496                 64891
# ...          ...        ...                   ...
# 20859884       1       4652                  5401
# 5106226        1       4653                  5409
# 17472408       1       4790                 56889
# 23010260       1       4850                 57410
# 14264713       1       9362                 99859
#
# [269 rows x 3 columns]

# %%
final_top_med
# Out:
#           counts  eve_index                       events
# 7449274      121      28623                acetaminophen
# 6972030      109      35454  sodium chloride 0.9%  flush
# 19287461      88      32006     hydromorphone (dilaudid)
# 16551244      74      34157                  ondansetron
# 6485610       73      30848              docusate sodium
# ...          ...        ...                          ...
# 22377981       1      18987                         O132
# 6530493        1      28339                       Z86718
# 14632428       1      28338                       Z86711
# 22628832       1      33102             maalox/lidocaine
# 13234604       1      19267                        O4212
#
# [430 rows x 3 columns]

# %%
final_top_output = pd.DataFrame({"Med": final_top_med["events"].values[0:10]
                                 ,"Diag": final_top_diag["events"].apply(lambda x: x[-3:]).values[0:10]
                                 ,"Proc":final_top_proc["events"].apply(lambda x: x[-3:]).values[0:10]})

# %%
final_top_output
# Out:
#                              Med Diag Proc
# 0                  acetaminophen  ide  909
# 1    sodium chloride 0.9%  flush  ose  909
# 2       hydromorphone (dilaudid)  311  329
# 3                    ondansetron  756  649
# 4                docusate sodium  891  630
# 5                      bisacodyl  us)  119
# 6                      ibuprofen  411  561
# 7                timetoken0-2day  390  909
# 8  oxycodone (immediate release)  741  419
# 9               lactated ringers  730  J36
